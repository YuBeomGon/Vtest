# %%
import numpy as np
import torch
import torch.nn as nn
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('dog.jpg')
img = cv2.resize(img, (224, 224))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img.shape
# Out:
# (224, 224, 3)

# %%
img_ = np.copy(img)
img_ = np.float32(img_)/255.0
# dct = cv2.dct(img_)
# ingdct1 = np.uint8(dct*255.)
dct_result = np.zeros(img_.shape)

# %%
# dct

# %%
from scipy.fft import dctn, idctn
img_ = np.float32(img_)/255.0
b = dctn(img_)
b.shape
# Out:
# (224, 224, 3)

# %%
# plt.imshow(b)

# %%
import numpy as np
from scipy.fftpack import dct, idct

def dct2(block):
    return dct(dct(block.T, norm='ortho').T, norm='ortho')

def idct2(block):
    return idct(idct(block.T, norm='ortho').T, norm='ortho')

for i in range(int(img.shape[0]/8)) :
    for j in range(int(img.shape[1]/8)) :
        dct_result[i*8:(i+1)*8, j*8:(j+1)*8,:] = dct2(np.float32(img[i*8:(i+1)*8, j*8:(j+1)*8,:])/255.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [101], line 3
#       1 for i in range(int(img.shape[0]/8)) :
#       2     for j in range(int(img.shape[1]/8)) :
# ----> 3         dct_result[i*8:(i+1)*8, j*8:(j+1)*8,:] = dct2(np.float32(img[i*8:(i+1)*8, j*8:(j+1)*8,:])/255.)
#
# NameError: name 'dct2' is not defined

# %%
plt.imshow(dct_result[:,:,:])
dct_result.shape
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)

# %%
# dct_result

# %%
plt.imshow(img)
